# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os

# %%
pwd
# Out:
# 'C:\\Users\\Dell\\.spyder-py3'

# %%
cd/Users/Dell/.spyder-py3
# Out:
# C:\Users\Dell\.spyder-py3

# %%
pwd
# Out:
# 'C:\\Users\\Dell\\.spyder-py3'

# %%
data=pd.read_csv("diabatis2.csv")

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.shape
# Out:
# (768, 9)

# %%
data.Outcome.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
data.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
featureList = ['Pregnancies','Glucose', 'BloodPressure',	'SkinThickness',	'Insulin',	'BMI']
print(data[featureList].isin({0}).sum())
# Out:
# Pregnancies      111
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# Insulin          374
# BMI               11
# dtype: int64

# %%
for col in featureList:
  data[col] = data[col].replace({ 0 : data[col].mean() })

# %%
data[featureList].isin({0}).sum()
# Out:
# Pregnancies      0
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# Insulin          0
# BMI              0
# dtype: int64

# %%
plt.figure(figsize=(10, 5))
sns.barplot('Outcome', 'Pregnancies', data=data, ) 

plt.title("Bars of Outcome and Pregnancies")
plt.xlabel("Outcome")
plt.ylabel("Pregnancies")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.barplot('Outcome', 'Glucose', data=data, ) 

plt.title("Bars of Outcome and Glucose")
plt.xlabel("Outcome")
plt.ylabel("Glucose")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.barplot('Outcome', 'BloodPressure', data=data, ) 

plt.title("Bars of Outcome and BloodPressure ")
plt.xlabel("Outcome")
plt.ylabel("BloodPressure ")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.barplot('Outcome', 'Insulin', data=data, ) 

plt.title("Bars of Outcome and Insulin ")
plt.xlabel("Outcome")
plt.ylabel("Insulin")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 7))

sns.heatmap(data.corr(), annot=True, linewidths=0.2, fmt='.1f', cmap='coolwarm') # cmap='RdYlBu'
plt.show()

# %%
#Data Visualization
#tmp = data.drop('Id', axis=1)
g = sns.pairplot(data,hue='Outcome', markers='+')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
from sklearn.model_selection import train_test_split

# %%
X=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0     6.000000    148.0           72.0      35.000000   79.799479  33.6
# 1     1.000000     85.0           66.0      29.000000   79.799479  26.6
# 2     8.000000    183.0           64.0      20.536458   79.799479  23.3
# 3     1.000000     89.0           66.0      23.000000   94.000000  28.1
# 4     3.845052    137.0           40.0      35.000000  168.000000  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier(n_neighbors=3) #this examines 3 neighbours for putting the new data into a class
model.fit(X_train,y_train)
prediction=model.predict(X_test)

# %%
from sklearn import metrics

# %%
print('The accuracy of the KNN is',metrics.accuracy_score(prediction,y_test))
# Out:
# The accuracy of the KNN is 0.70995670995671

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier=RandomForestClassifier()
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predict=classifier.predict(X_test)
print("The Accuracy of Random Forest is:",metrics.accuracy_score(predict,y_test))
# Out:
# The Accuracy of Random Forest is: 0.7662337662337663

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df=data.drop(['Pregnancies'],axis=1)

# %%
df=data.drop(['SkinThickness','Pregnancies'],axis=1)

# %%
df.head()
# Out:
#    Glucose  BloodPressure     Insulin   BMI  DiabetesPedigreeFunction  Age  \
# 0    148.0           72.0   79.799479  33.6                     0.627   50
# 1     85.0           66.0   79.799479  26.6                     0.351   31
# 2    183.0           64.0   79.799479  23.3                     0.672   32
# 3     89.0           66.0   94.000000  28.1                     0.167   21
# 4    137.0           40.0  168.000000  43.1                     2.288   33
#
#    Outcome
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1

# %%
df.tail()
# Out:
#      Glucose  BloodPressure     Insulin   BMI  DiabetesPedigreeFunction  Age  \
# 763    101.0           76.0  180.000000  32.9                     0.171   63
# 764    122.0           70.0   79.799479  36.8                     0.340   27
# 765    121.0           72.0  112.000000  26.2                     0.245   30
# 766    126.0           60.0   79.799479  30.1                     0.349   47
# 767     93.0           70.0   79.799479  30.4                     0.315   23
#
#      Outcome
# 763        0
# 764        0
# 765        0
# 766        1
# 767        0

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
X.head()
# Out:
#    Glucose  BloodPressure     Insulin   BMI  DiabetesPedigreeFunction  Age
# 0    148.0           72.0   79.799479  33.6                     0.627   50
# 1     85.0           66.0   79.799479  26.6                     0.351   31
# 2    183.0           64.0   79.799479  23.3                     0.672   32
# 3     89.0           66.0   94.000000  28.1                     0.167   21
# 4    137.0           40.0  168.000000  43.1                     2.288   33

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
X_train.head()
# Out:
#      Glucose  BloodPressure    Insulin   BMI  DiabetesPedigreeFunction  Age
# 580    151.0           90.0  79.799479  42.1                     0.371   21
# 418     83.0           68.0  79.799479  18.2                     0.624   27
# 764    122.0           70.0  79.799479  36.8                     0.340   27
# 363    146.0           78.0  79.799479  38.5                     0.520   67
# 757    123.0           72.0  79.799479  36.3                     0.258   52

# %%
model=KNeighborsClassifier(n_neighbors=3) #this examines 3 neighbours for putting the new data into a class
model.fit(X_train,y_train)
prediction=model.predict(X_test)

# %%
print('The accuracy of the KNN is',metrics.accuracy_score(prediction,y_test))
# Out:
# The accuracy of the KNN is 0.7012987012987013

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier=RandomForestClassifier()
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=classifier.predict(X_test)

# %%
print('The accuracy of the Random Forest is',metrics.accuracy_score(y_pred,y_test))
# Out:
# The accuracy of the Random Forest is 0.7619047619047619

# %%
import pickle
pickle_out=open("classifier.pkl",'wb')
pickle.dump(classifier,pickle_out)
pickle_out.close()

# %%
classifier.predict([[148,72.0,33.6,0.627,50]])
# Out:
# array([1], dtype=int64)
